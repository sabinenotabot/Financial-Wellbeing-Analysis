# %% [markdown]
# ## Retrieving and cleaning data

# %%
#Loading relevant packages
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np

# %%
#Retrieving data 
df = pd.read_csv("NFWBS_PUF_2016_data.csv")

# %%
#Getting an initial look at the data 
df.head()
# Out:
#    PUF_ID  sample  fpl  SWB_1  SWB_2  SWB_3  FWBscore  FWB1_1  FWB1_2  FWB1_3  \
# 0   10350       2    3      5      5      6        55       3       3       3
# 1    7740       1    3      6      6      6        51       2       2       3
# 2   13699       1    3      4      3      4        49       3       3       3
# 3    7267       1    3      6      6      6        49       3       3       3
# 4    7375       1    3      4      4      4        49       3       3       3
#
#    ...  PPMSACAT  PPREG4  PPREG9  PPT01  PPT25  PPT612  PPT1317  PPT18OV  \
# 0  ...         1       4       8      0      0       0        0        1
# 1  ...         1       2       3      0      0       0        0        2
# 2  ...         1       4       9      0      0       0        1        2
# 3  ...         1       3       7      0      0       0        0        1
# 4  ...         1       2       4      0      0       1        0        4
#
#    PCTLT200FPL   finalwt
# 0            0  0.367292
# 1            0  1.327561
# 2            1  0.835156
# 3            0  1.410871
# 4            1  4.260668
#
# [5 rows x 217 columns]

# %%
df.shape
# Out:
# (6394, 217)

# %%
#Filtering out columns of interest
df=df[['PPINCIMP','EMPLOY','FWBscore', 'FSscore','HHEDUC','HEALTH','PRODHAVE_1','PRODHAVE_2','PRODHAVE_3','PRODHAVE_4','PRODHAVE_5','PRODHAVE_6','PRODHAVE_7','PRODHAVE_8']]

# %%
#Relabeling columns for easy comprehension
df.rename(columns={'PPINCIMP':'income',
                   'FWBscore':'financial_wellbeing',
                   'FSscore':'financial_skill',
                          'EMPLOY':'employment',
                          'PRODHAVE_1':'savings_account',
                           'PRODHAVE_2':'life_insurance',
                           'PRODHAVE_3':'health_insurance',
                           'PRODHAVE_4':'retirement_account',
                           'PRODHAVE_5':'pension',
                           'PRODHAVE_6': 'investment',
                           'PRODHAVE_7':'education_saving',
                           'PRODHAVE_8':'student_loan',
                           'HEALTH': 'health',
                            'HHEDUC': 'education'}, 
                 inplace=True)

df.head()
# Out:
#    income  employment  financial_wellbeing  financial_skill  education  \
# 0       7           8                   55               44          4
# 1       6           2                   51               43          2
# 2       6           2                   49               42          3
# 3       8          99                   49               42         -1
# 4       7           2                   49               42          2
#
#    health  savings_account  life_insurance  health_insurance  \
# 0       2                1               1                 1
# 1       3                1               0                 1
# 2       3                1               1                 0
# 3      -1                0               0                 0
# 4       3                1               0                 0
#
#    retirement_account  pension  investment  education_saving  student_loan
# 0                   1        1           0                 0             0
# 1                   0        0           0                 0             0
# 2                   1        1           0                 0             0
# 3                   0        0           0                 0             0
# 4                   1        0           0                 0             0

# %%
#Checking the number of junk values 
print((df == -1).sum())
print((df.financial_wellbeing == -4).sum())
print((df.employment == 99).sum())
# Out:
# income                  0
# employment              0
# financial_wellbeing     4
# financial_skill         8
# education              59
# health                 53
# savings_account         0
# life_insurance          0
# health_insurance        0
# retirement_account      0
# pension                 0
# investment              0
# education_saving        0
# student_loan            0
# dtype: int64
# 1
# 116

# %%
#Removing rows with junk values
df = df[(df != -1).all(axis=1)]
df = df[df.financial_wellbeing != -4]
df = df[df.employment != 99]

# %%
#Relabeling categorical variables 
df = df.replace({"employment":{
  1: "Self-employed",
  2: "Work full-time for an employer or the military",
  3: "Work part-time for an employer or the military",
  4: "Homemaker",
  5: "Full-time student",
  6: "Permanently sick, disabled or unable to work",
  7: "Unemployed or temporarily laid off",
  8: "Retired",
  99: "Refused"
},
"education":{
  1: "Less than high school",
  2: "High school degree/GED",
  3: "Some college/Associate",
  4: "Bachelors degree",
  5: "Graduate/professional degree"
},
"income":{
  1: 20000,
  2: 25000,
  3: 35000,
  4: 45000,
  5: 55000,
  6: 67500,
  7: 87500,
  8: 125000,
  9: 200000
}})

df.head()
# Out:
#    income                                      employment  \
# 0   87500                                         Retired
# 1   67500  Work full-time for an employer or the military
# 2   67500  Work full-time for an employer or the military
# 4   87500  Work full-time for an employer or the military
# 5   87500  Work full-time for an employer or the military
#
#    financial_wellbeing  financial_skill               education  health  \
# 0                   55               44        Bachelors degree       2
# 1                   51               43  High school degree/GED       3
# 2                   49               42  Some college/Associate       3
# 4                   49               42  High school degree/GED       3
# 5                   67               57        Bachelors degree       5
#
#    savings_account  life_insurance  health_insurance  retirement_account  \
# 0                1               1                 1                   1
# 1                1               0                 1                   0
# 2                1               1                 0                   1
# 4                1               0                 0                   1
# 5                1               1                 1                   1
#
#    pension  investment  education_saving  student_loan
# 0        1           0                 0             0
# 1        0           0                 0             0
# 2        1           0                 0             0
# 4        0           0                 0             0
# 5        0           0                 0             1

# %% [markdown]
# ## Exploratory Analysis

# %%
#Seperating numerical and categorical values
df_num = df[['income', 'health','financial_skill','financial_wellbeing',]]
df_cat = df[['education', 'employment','savings_account','life_insurance','health_insurance','retirement_account','pension','investment','education_saving','student_loan']]

# %%
#Creating histograms
for i in df_num.columns:
    plt.hist(df_num[i])
    plt.title(i)
    plt.show()

# %%
#Creating bar charts, rotating labels to fit them into image
for i in df_cat.columns:
    sns.barplot(df_cat[i].value_counts().index,df_cat[i].value_counts()).set_title(i)
    
    if i== 'education' or i == 'employment':
        plt.xticks(rotation=80)
    
    plt.show()

# %%
#Creating dummy variables and adding to our original dataframe

df = pd.concat([df, pd.get_dummies(df['employment'])], axis=1) 

df = pd.concat([df, pd.get_dummies(df['education'])], axis=1)

#Checking new dataframe
df.head()
# Out:
#    income                                      employment  \
# 0   87500                                         Retired
# 1   67500  Work full-time for an employer or the military
# 2   67500  Work full-time for an employer or the military
# 4   87500  Work full-time for an employer or the military
# 5   87500  Work full-time for an employer or the military
#
#    financial_wellbeing  financial_skill               education  health  \
# 0                   55               44        Bachelors degree       2
# 1                   51               43  High school degree/GED       3
# 2                   49               42  Some college/Associate       3
# 4                   49               42  High school degree/GED       3
# 5                   67               57        Bachelors degree       5
#
#    savings_account  life_insurance  health_insurance  retirement_account  ...  \
# 0                1               1                 1                   1  ...
# 1                1               0                 1                   0  ...
# 2                1               1                 0                   1  ...
# 4                1               0                 0                   1  ...
# 5                1               1                 1                   1  ...
#
#    Retired  Self-employed  Unemployed or temporarily laid off  \
# 0        1              0                                   0
# 1        0              0                                   0
# 2        0              0                                   0
# 4        0              0                                   0
# 5        0              0                                   0
#
#    Work full-time for an employer or the military  \
# 0                                               0
# 1                                               1
# 2                                               1
# 4                                               1
# 5                                               1
#
#    Work part-time for an employer or the military  Bachelors degree  \
# 0                                               0                 1
# 1                                               0                 0
# 2                                               0                 0
# 4                                               0                 0
# 5                                               0                 1
#
#    Graduate/professional degree  High school degree/GED  \
# 0                             0                       0
# 1                             0                       1
# 2                             0                       0
# 4                             0                       1
# 5                             0                       0
#
#    Less than high school  Some college/Associate
# 0                      0                       0
# 1                      0                       0
# 2                      0                       1
# 4                      0                       0
# 5                      0                       0
#
# [5 rows x 27 columns]

# %%
#Creating pivot tables to get an initial understanding of the impact of financial products

df_products = df[['savings_account','life_insurance','health_insurance','retirement_account','pension','investment','education_saving','student_loan']]

for i in df_products.columns:
    table = pd.pivot_table(df, values=['financial_wellbeing'], index=[i],
                   aggfunc=[np.mean,np.median])
    table.loc['difference'] = np.abs(table.loc[0].sub(table.loc[1], fill_value=0))
    print(table)
    print()
# Out:
#                                mean              median
#                 financial_wellbeing financial_wellbeing
# savings_account
# 0                         48.716553                49.0
# 1                         57.360794                57.0
# difference                 8.644241                 8.0
#
#                               mean              median
#                financial_wellbeing financial_wellbeing
# life_insurance
# 0                        53.602288                53.0
# 1                        58.451553                58.0
# difference                4.849265                 5.0
#
#                                 mean              median
#                  financial_wellbeing financial_wellbeing
# health_insurance
# 0                          51.194141                51.0
# 1                          58.055109                58.0
# difference                  6.860968                 7.0
#
#                                   mean              median
#                    financial_wellbeing financial_wellbeing
# retirement_account
# 0                            50.428462                50.0
# 1                            60.231300                60.0
# difference                    9.802838                10.0
#
#                           mean              median
#            financial_wellbeing financial_wellbeing
# pension
# 0                    53.046278                53.0
# 1                    62.034128                61.0
# difference            8.987850                 8.0
#
#                           mean              median
#            financial_wellbeing financial_wellbeing
# investment
# 0                    52.595519                53.0
# 1                    63.704992                63.0
# difference           11.109474                10.0
#
#                                 mean              median
#                  financial_wellbeing financial_wellbeing
# education_saving
# 0                          55.797801                56.0
# 1                          61.027363                60.0
# difference                  5.229562                 4.0
#
#                             mean              median
#              financial_wellbeing financial_wellbeing
# student_loan
# 0                      57.005062                57.0
# 1                      50.919010                51.0
# difference              6.086052                 6.0

# %% [markdown]
# ## Regression Analysis

# %%
#Importing packages

import statsmodels.api as sm
from statsmodels.formula.api import ols

# %%
#Running a univariate regression for each financial product

r_squared = []
for i in df_products.columns:
       
    X = df_products[i] 
    y = df['financial_wellbeing']
    X = sm.add_constant(X)
    est = sm.OLS(y, X).fit()
    
    r_squared.append(est.rsquared)
    
    print(est.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     financial_wellbeing   R-squared:                       0.046
# Model:                             OLS   Adj. R-squared:                  0.046
# Method:                  Least Squares   F-statistic:                     299.7
# Date:                 Fri, 18 Sep 2020   Prob (F-statistic):           1.27e-65
# Time:                         16:30:33   Log-Likelihood:                -25134.
# No. Observations:                 6223   AIC:                         5.027e+04
# Df Residuals:                     6221   BIC:                         5.029e+04
# Df Model:                            1
# Covariance Type:             nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# const              48.7166      0.463    105.319      0.000      47.810      49.623
# savings_account     8.6442      0.499     17.313      0.000       7.665       9.623
# ==============================================================================
# Omnibus:                       21.371   Durbin-Watson:                   1.991
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.066
# Skew:                          -0.005   Prob(JB):                     8.05e-07
# Kurtosis:                       3.329   Cond. No.                         5.13
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     financial_wellbeing   R-squared:                       0.030
# Model:                             OLS   Adj. R-squared:                  0.030
# Method:                  Least Squares   F-statistic:                     190.2
# Date:                 Fri, 18 Sep 2020   Prob (F-statistic):           1.20e-42
# Time:                         16:30:33   Log-Likelihood:                -25187.
# No. Observations:                 6223   AIC:                         5.038e+04
# Df Residuals:                     6221   BIC:                         5.039e+04
# Df Model:                            1
# Covariance Type:             nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             53.6023      0.254    210.925      0.000      53.104      54.100
# life_insurance     4.8493      0.352     13.792      0.000       4.160       5.539
# ==============================================================================
# Omnibus:                       24.728   Durbin-Watson:                   2.003
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               31.612
# Skew:                           0.054   Prob(JB):                     1.37e-07
# Kurtosis:                       3.332   Cond. No.                         2.67
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     financial_wellbeing   R-squared:                       0.048
# Model:                             OLS   Adj. R-squared:                  0.048
# Method:                  Least Squares   F-statistic:                     313.4
# Date:                 Fri, 18 Sep 2020   Prob (F-statistic):           1.82e-68
# Time:                         16:30:33   Log-Likelihood:                -25128.
# No. Observations:                 6223   AIC:                         5.026e+04
# Df Residuals:                     6221   BIC:                         5.027e+04
# Df Model:                            1
# Covariance Type:             nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               51.1941      0.329    155.658      0.000      50.549      51.839
# health_insurance     6.8610      0.388     17.704      0.000       6.101       7.621
# ==============================================================================
# Omnibus:                       32.019   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               45.059
# Skew:                           0.020   Prob(JB):                     1.64e-10
# Kurtosis:                       3.415   Cond. No.                         3.55
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     financial_wellbeing   R-squared:                       0.118
# Model:                             OLS   Adj. R-squared:                  0.118
# Method:                  Least Squares   F-statistic:                     833.9
# Date:                 Fri, 18 Sep 2020   Prob (F-statistic):          3.40e-172
# Time:                         16:30:33   Log-Likelihood:                -24889.
# No. Observations:                 6223   AIC:                         4.978e+04
# Df Residuals:                     6221   BIC:                         4.980e+04
# Df Model:                            1
# Covariance Type:             nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 50.4285      0.259    194.697      0.000      49.921      50.936
# retirement_account     9.8028      0.339     28.878      0.000       9.137      10.468
# ==============================================================================
# Omnibus:                       55.645   Durbin-Watson:                   2.000
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               79.960
# Skew:                           0.099   Prob(JB):                     4.33e-18
# Kurtosis:                       3.519   Cond. No.                         2.86
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     financial_wellbeing   R-squared:                       0.092
# Model:                             OLS   Adj. R-squared:                  0.092
# Method:                  Least Squares   F-statistic:                     631.5
# Date:                 Fri, 18 Sep 2020   Prob (F-statistic):          8.34e-133
# Time:                         16:30:33   Log-Likelihood:                -24980.
# No. Observations:                 6223   AIC:                         4.996e+04
# Df Residuals:                     6221   BIC:                         4.998e+04
# Df Model:                            1
# Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         53.0463      0.210    252.971      0.000      52.635      53.457
# pension        8.9878      0.358     25.129      0.000       8.287       9.689
# ==============================================================================
# Omnibus:                       22.193   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               28.998
# Skew:                           0.025   Prob(JB):                     5.05e-07
# Kurtosis:                       3.331   Cond. No.                         2.42
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     financial_wellbeing   R-squared:                       0.136
# Model:                             OLS   Adj. R-squared:                  0.135
# Method:                  Least Squares   F-statistic:                     975.2
# Date:                 Fri, 18 Sep 2020   Prob (F-statistic):          5.36e-199
# Time:                         16:30:33   Log-Likelihood:                -24827.
# No. Observations:                 6223   AIC:                         4.966e+04
# Df Residuals:                     6221   BIC:                         4.967e+04
# Df Model:                            1
# Covariance Type:             nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         52.5955      0.201    261.897      0.000      52.202      52.989
# investment    11.1095      0.356     31.227      0.000      10.412      11.807
# ==============================================================================
# Omnibus:                       36.554   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.667
# Skew:                           0.027   Prob(JB):                     3.66e-12
# Kurtosis:                       3.447   Cond. No.                         2.42
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     financial_wellbeing   R-squared:                       0.008
# Model:                             OLS   Adj. R-squared:                  0.008
# Method:                  Least Squares   F-statistic:                     52.43
# Date:                 Fri, 18 Sep 2020   Prob (F-statistic):           5.00e-13
# Time:                         16:30:33   Log-Likelihood:                -25254.
# No. Observations:                 6223   AIC:                         5.051e+04
# Df Residuals:                     6221   BIC:                         5.053e+04
# Df Model:                            1
# Covariance Type:             nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               55.7978      0.184    303.961      0.000      55.438      56.158
# education_saving     5.2296      0.722      7.241      0.000       3.814       6.645
# ==============================================================================
# Omnibus:                       17.580   Durbin-Watson:                   1.995
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.384
# Skew:                           0.004   Prob(JB):                     1.38e-05
# Kurtosis:                       3.294   Cond. No.                         4.09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     financial_wellbeing   R-squared:                       0.023
# Model:                             OLS   Adj. R-squared:                  0.023
# Method:                  Least Squares   F-statistic:                     146.0
# Date:                 Fri, 18 Sep 2020   Prob (F-statistic):           3.00e-33
# Time:                         16:30:33   Log-Likelihood:                -25208.
# No. Observations:                 6223   AIC:                         5.042e+04
# Df Residuals:                     6221   BIC:                         5.043e+04
# Df Model:                            1
# Covariance Type:             nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const           57.0051      0.190    299.473      0.000      56.632      57.378
# student_loan    -6.0861      0.504    -12.085      0.000      -7.073      -5.099
# ==============================================================================
# Omnibus:                       18.007   Durbin-Watson:                   1.997
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.511
# Skew:                          -0.032   Prob(JB):                     1.29e-05
# Kurtosis:                       3.287   Cond. No.                         2.92
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
#Creating a table with R squared values to compare model fit
results1 = {'Product': df_products.columns, 'r_squared': r_squared}

df_results1 = pd.DataFrame(results1)

print(df_results1)
# Out:
#               Product  r_squared
# 0     savings_account   0.045967
# 1      life_insurance   0.029670
# 2    health_insurance   0.047967
# 3  retirement_account   0.118207
# 4             pension   0.092152
# 5          investment   0.135511
# 6    education_saving   0.008357
# 7        student_loan   0.022936

# %%
#Visualizing regression using boxplots

for i in df_products.columns:
        plt.figure(i)
        sns.boxplot(x=df_cat[i], y="financial_wellbeing", data=df)

# %%
#Stroring dummy variables for easy use
education = ['Bachelors degree','Graduate/professional degree','High school degree/GED','Less than high school'] 
employment = ['Retired', 'Self-employed','Unemployed or temporarily laid off','Work full-time for an employer or the military', 'Work part-time for an employer or the military'] 


#Running a multivariate regression for each financial product, including control variables

for i in df_products.columns:
       
    X = df[[i, 'income', 'health', 'financial_skill'] + education + employment] 
    y = df['financial_wellbeing']
    X = sm.add_constant(X)
    est = sm.OLS(y, X).fit()
    
    print(est.summary())
# Out:
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     financial_wellbeing   R-squared:                       0.427
# Model:                             OLS   Adj. R-squared:                  0.426
# Method:                  Least Squares   F-statistic:                     355.6
# Date:                 Fri, 18 Sep 2020   Prob (F-statistic):               0.00
# Time:                         16:30:36   Log-Likelihood:                -23549.
# No. Observations:                 6223   AIC:                         4.713e+04
# Df Residuals:                     6209   BIC:                         4.722e+04
# Df Model:                           13
# Covariance Type:             nonrobust
# ==================================================================================================================
#                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------
# const                                             16.7502      0.816     20.539      0.000      15.151      18.349
# savings_account                                    3.4063      0.406      8.387      0.000       2.610       4.202
# income                                          5.793e-05   2.83e-06     20.446      0.000    5.24e-05    6.35e-05
# health                                             2.0902      0.159     13.124      0.000       1.778       2.402
# financial_skill                                    0.4091      0.012     35.439      0.000       0.386       0.432
# Bachelors degree                                   0.5341      0.383      1.395      0.163      -0.216       1.284
# Graduate/professional degree                       1.1810      0.400      2.952      0.003       0.397       1.965
# High school degree/GED                             1.1638      0.415      2.803      0.005       0.350       1.978
# Less than high school                             -1.4987      0.851     -1.761      0.078      -3.167       0.170
# Retired                                            9.3799      0.451     20.800      0.000       8.496      10.264
# Self-employed                                      1.4244      0.646      2.204      0.028       0.158       2.691
# Unemployed or temporarily laid off                -2.7848      0.778     -3.578      0.000      -4.311      -1.259
# Work full-time for an employer or the military     0.4683      0.441      1.062      0.288      -0.396       1.333
# Work part-time for an employer or the military     0.8427      0.636      1.325      0.185      -0.404       2.089
# ==============================================================================
# Omnibus:                      178.396   Durbin-Watson:                   1.983
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              294.313
# Skew:                          -0.261   Prob(JB):                     1.23e-64
# Kurtosis:                       3.929   Cond. No.                     8.08e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 8.08e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     financial_wellbeing   R-squared:                       0.422
# Model:                             OLS   Adj. R-squared:                  0.421
# Method:                  Least Squares   F-statistic:                     349.2
# Date:                 Fri, 18 Sep 2020   Prob (F-statistic):               0.00
# Time:                         16:30:36   Log-Likelihood:                -23573.
# No. Observations:                 6223   AIC:                         4.717e+04
# Df Residuals:                     6209   BIC:                         4.727e+04
# Df Model:                           13
# Covariance Type:             nonrobust
# ==================================================================================================================
#                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------
# const                                             18.7718      0.773     24.297      0.000      17.257      20.286
# life_insurance                                     1.3304      0.284      4.680      0.000       0.773       1.888
# income                                          5.807e-05   2.86e-06     20.284      0.000    5.25e-05    6.37e-05
# health                                             2.1247      0.160     13.291      0.000       1.811       2.438
# financial_skill                                    0.4097      0.012     35.340      0.000       0.387       0.432
# Bachelors degree                                   0.6318      0.384      1.646      0.100      -0.121       1.385
# Graduate/professional degree                       1.2829      0.401      3.197      0.001       0.496       2.070
# High school degree/GED                             0.9582      0.416      2.304      0.021       0.143       1.774
# Less than high school                             -2.0975      0.850     -2.468      0.014      -3.764      -0.431
# Retired                                            9.5490      0.452     21.110      0.000       8.662      10.436
# Self-employed                                      1.3329      0.649      2.055      0.040       0.061       2.604
# Unemployed or temporarily laid off                -2.9651      0.781     -3.795      0.000      -4.497      -1.434
# Work full-time for an employer or the military     0.4807      0.444      1.082      0.279      -0.390       1.351
# Work part-time for an employer or the military     0.9012      0.638      1.412      0.158      -0.350       2.153
# ==============================================================================
# Omnibus:                      183.287   Durbin-Watson:                   1.990
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              313.424
# Skew:                          -0.256   Prob(JB):                     8.73e-69
# Kurtosis:                       3.973   Cond. No.                     7.96e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.96e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     financial_wellbeing   R-squared:                       0.424
# Model:                             OLS   Adj. R-squared:                  0.423
# Method:                  Least Squares   F-statistic:                     351.5
# Date:                 Fri, 18 Sep 2020   Prob (F-statistic):               0.00
# Time:                         16:30:36   Log-Likelihood:                -23564.
# No. Observations:                 6223   AIC:                         4.716e+04
# Df Residuals:                     6209   BIC:                         4.725e+04
# Df Model:                           13
# Covariance Type:             nonrobust
# ==================================================================================================================
#                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------
# const                                             18.2314      0.781     23.356      0.000      16.701      19.762
# health_insurance                                   2.0053      0.321      6.253      0.000       1.377       2.634
# income                                          5.735e-05   2.86e-06     20.044      0.000    5.17e-05     6.3e-05
# health                                             2.0976      0.160     13.137      0.000       1.785       2.411
# financial_skill                                    0.4102      0.012     35.453      0.000       0.388       0.433
# Bachelors degree                                   0.5275      0.384      1.374      0.170      -0.225       1.280
# Graduate/professional degree                       1.2008      0.401      2.994      0.003       0.415       1.987
# High school degree/GED                             1.0139      0.416      2.440      0.015       0.199       1.829
# Less than high school                             -1.9456      0.850     -2.290      0.022      -3.611      -0.280
# Retired                                            9.3857      0.453     20.700      0.000       8.497      10.275
# Self-employed                                      1.3915      0.648      2.148      0.032       0.122       2.661
# Unemployed or temporarily laid off                -2.8830      0.780     -3.695      0.000      -4.413      -1.353
# Work full-time for an employer or the military     0.4660      0.443      1.053      0.292      -0.402       1.334
# Work part-time for an employer or the military     0.9284      0.637      1.456      0.145      -0.321       2.178
# ==============================================================================
# Omnibus:                      182.206   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              309.742
# Skew:                          -0.256   Prob(JB):                     5.50e-68
# Kurtosis:                       3.965   Cond. No.                     7.98e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.98e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     financial_wellbeing   R-squared:                       0.438
# Model:                             OLS   Adj. R-squared:                  0.437
# Method:                  Least Squares   F-statistic:                     371.9
# Date:                 Fri, 18 Sep 2020   Prob (F-statistic):               0.00
# Time:                         16:30:36   Log-Likelihood:                -23489.
# No. Observations:                 6223   AIC:                         4.701e+04
# Df Residuals:                     6209   BIC:                         4.710e+04
# Df Model:                           13
# Covariance Type:             nonrobust
# ==================================================================================================================
#                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------
# const                                             19.4736      0.760     25.623      0.000      17.984      20.963
# retirement_account                                 4.3754      0.315     13.878      0.000       3.757       4.993
# income                                          5.023e-05   2.88e-06     17.425      0.000    4.46e-05    5.59e-05
# health                                             2.0715      0.158     13.132      0.000       1.762       2.381
# financial_skill                                    0.3956      0.011     34.432      0.000       0.373       0.418
# Bachelors degree                                   0.2271      0.380      0.597      0.550      -0.518       0.972
# Graduate/professional degree                       0.8731      0.397      2.199      0.028       0.095       1.652
# High school degree/GED                             1.0977      0.410      2.674      0.008       0.293       1.902
# Less than high school                             -1.4507      0.839     -1.728      0.084      -3.096       0.195
# Retired                                            8.6118      0.452     19.056      0.000       7.726       9.498
# Self-employed                                      1.0706      0.640      1.673      0.094      -0.184       2.325
# Unemployed or temporarily laid off                -3.1366      0.770     -4.076      0.000      -4.645      -1.628
# Work full-time for an employer or the military    -0.7182      0.448     -1.605      0.109      -1.595       0.159
# Work part-time for an employer or the military     0.1728      0.632      0.273      0.785      -1.066       1.412
# ==============================================================================
# Omnibus:                      159.042   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              277.747
# Skew:                          -0.215   Prob(JB):                     4.88e-61
# Kurtosis:                       3.941   Cond. No.                     7.98e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.98e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     financial_wellbeing   R-squared:                       0.429
# Model:                             OLS   Adj. R-squared:                  0.428
# Method:                  Least Squares   F-statistic:                     359.1
# Date:                 Fri, 18 Sep 2020   Prob (F-statistic):               0.00
# Time:                         16:30:36   Log-Likelihood:                -23536.
# No. Observations:                 6223   AIC:                         4.710e+04
# Df Residuals:                     6209   BIC:                         4.719e+04
# Df Model:                           13
# Covariance Type:             nonrobust
# ==================================================================================================================
#                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------
# const                                             19.1125      0.765     24.976      0.000      17.612      20.613
# pension                                            3.1520      0.321      9.834      0.000       2.524       3.780
# income                                          5.603e-05   2.85e-06     19.690      0.000    5.04e-05    6.16e-05
# health                                             2.1273      0.159     13.387      0.000       1.816       2.439
# financial_skill                                    0.4082      0.012     35.434      0.000       0.386       0.431
# Bachelors degree                                   0.6513      0.382      1.707      0.088      -0.097       1.399
# Graduate/professional degree                       1.1207      0.399      2.807      0.005       0.338       1.903
# High school degree/GED                             0.9506      0.413      2.299      0.022       0.140       1.761
# Less than high school                             -2.0059      0.844     -2.377      0.017      -3.660      -0.351
# Retired                                            8.1922      0.474     17.270      0.000       7.262       9.122
# Self-employed                                      1.3887      0.645      2.154      0.031       0.125       2.653
# Unemployed or temporarily laid off                -3.0697      0.775     -3.959      0.000      -4.590      -1.550
# Work full-time for an employer or the military     0.3861      0.440      0.877      0.380      -0.477       1.249
# Work part-time for an employer or the military     0.6540      0.635      1.030      0.303      -0.591       1.899
# ==============================================================================
# Omnibus:                      182.675   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              308.869
# Skew:                          -0.259   Prob(JB):                     8.51e-68
# Kurtosis:                       3.961   Cond. No.                     7.96e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.96e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     financial_wellbeing   R-squared:                       0.437
# Model:                             OLS   Adj. R-squared:                  0.435
# Method:                  Least Squares   F-statistic:                     370.1
# Date:                 Fri, 18 Sep 2020   Prob (F-statistic):               0.00
# Time:                         16:30:36   Log-Likelihood:                -23495.
# No. Observations:                 6223   AIC:                         4.702e+04
# Df Residuals:                     6209   BIC:                         4.711e+04
# Df Model:                           13
# Covariance Type:             nonrobust
# ==================================================================================================================
#                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------
# const                                             20.2132      0.765     26.423      0.000      18.714      21.713
# investment                                         4.2698      0.319     13.380      0.000       3.644       4.895
# income                                          5.182e-05   2.86e-06     18.092      0.000    4.62e-05    5.74e-05
# health                                             2.0743      0.158     13.136      0.000       1.765       2.384
# financial_skill                                    0.3923      0.012     34.013      0.000       0.370       0.415
# Bachelors degree                                   0.2841      0.380      0.747      0.455      -0.461       1.029
# Graduate/professional degree                       0.7218      0.399      1.811      0.070      -0.060       1.503
# High school degree/GED                             0.9822      0.411      2.391      0.017       0.177       1.787
# Less than high school                             -2.0744      0.838     -2.475      0.013      -3.717      -0.431
# Retired                                            8.7132      0.452     19.294      0.000       7.828       9.599
# Self-employed                                      0.9585      0.641      1.495      0.135      -0.298       2.215
# Unemployed or temporarily laid off                -3.0826      0.770     -4.001      0.000      -4.593      -1.572
# Work full-time for an employer or the military     0.4753      0.437      1.089      0.276      -0.380       1.331
# Work part-time for an employer or the military     0.6681      0.631      1.059      0.290      -0.568       1.905
# ==============================================================================
# Omnibus:                      171.292   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              287.045
# Skew:                          -0.246   Prob(JB):                     4.67e-63
# Kurtosis:                       3.930   Cond. No.                     7.98e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.98e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     financial_wellbeing   R-squared:                       0.420
# Model:                             OLS   Adj. R-squared:                  0.419
# Method:                  Least Squares   F-statistic:                     346.3
# Date:                 Fri, 18 Sep 2020   Prob (F-statistic):               0.00
# Time:                         16:30:36   Log-Likelihood:                -23584.
# No. Observations:                 6223   AIC:                         4.720e+04
# Df Residuals:                     6209   BIC:                         4.729e+04
# Df Model:                           13
# Covariance Type:             nonrobust
# ==================================================================================================================
#                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------
# const                                             19.0591      0.773     24.662      0.000      17.544      20.574
# education_saving                                  -0.2233      0.574     -0.389      0.697      -1.349       0.902
# income                                          6.015e-05   2.87e-06     20.957      0.000    5.45e-05    6.58e-05
# health                                             2.1191      0.160     13.225      0.000       1.805       2.433
# financial_skill                                    0.4124      0.012     35.509      0.000       0.390       0.435
# Bachelors degree                                   0.6625      0.385      1.722      0.085      -0.092       1.417
# Graduate/professional degree                       1.3173      0.404      3.265      0.001       0.526       2.108
# High school degree/GED                             0.9286      0.417      2.229      0.026       0.112       1.745
# Less than high school                             -2.3322      0.850     -2.744      0.006      -3.999      -0.666
# Retired                                            9.7117      0.452     21.474      0.000       8.825      10.598
# Self-employed                                      1.3037      0.650      2.006      0.045       0.030       2.578
# Unemployed or temporarily laid off                -3.1734      0.781     -4.061      0.000      -4.705      -1.642
# Work full-time for an employer or the military     0.6938      0.443      1.568      0.117      -0.174       1.561
# Work part-time for an employer or the military     0.9420      0.639      1.473      0.141      -0.312       2.196
# ==============================================================================
# Omnibus:                      188.855   Durbin-Watson:                   1.988
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              317.890
# Skew:                          -0.268   Prob(JB):                     9.35e-70
# Kurtosis:                       3.968   Cond. No.                     7.95e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.95e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
#                              OLS Regression Results
# ===============================================================================
# Dep. Variable:     financial_wellbeing   R-squared:                       0.430
# Model:                             OLS   Adj. R-squared:                  0.429
# Method:                  Least Squares   F-statistic:                     360.1
# Date:                 Fri, 18 Sep 2020   Prob (F-statistic):               0.00
# Time:                         16:30:37   Log-Likelihood:                -23532.
# No. Observations:                 6223   AIC:                         4.709e+04
# Df Residuals:                     6209   BIC:                         4.719e+04
# Df Model:                           13
# Covariance Type:             nonrobust
# ==================================================================================================================
#                                                      coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------------------------
# const                                             20.1200      0.772     26.076      0.000      18.607      21.633
# student_loan                                      -4.1283      0.405    -10.183      0.000      -4.923      -3.334
# income                                          5.826e-05   2.82e-06     20.657      0.000    5.27e-05    6.38e-05
# health                                             2.1824      0.159     13.730      0.000       1.871       2.494
# financial_skill                                    0.4042      0.012     35.041      0.000       0.382       0.427
# Bachelors degree                                   0.9523      0.383      2.490      0.013       0.202       1.702
# Graduate/professional degree                       1.7128      0.401      4.275      0.000       0.927       2.498
# High school degree/GED                             0.5018      0.415      1.208      0.227      -0.312       1.316
# Less than high school                             -2.7757      0.844     -3.289      0.001      -4.430      -1.121
# Retired                                            9.0209      0.453     19.906      0.000       8.133       9.909
# Self-employed                                      1.0034      0.645      1.556      0.120      -0.261       2.268
# Unemployed or temporarily laid off                -3.2988      0.775     -4.256      0.000      -4.818      -1.779
# Work full-time for an employer or the military     0.7571      0.439      1.725      0.085      -0.103       1.618
# Work part-time for an employer or the military     0.7712      0.634      1.216      0.224      -0.472       2.015
# ==============================================================================
# Omnibus:                      183.920   Durbin-Watson:                   1.989
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              306.452
# Skew:                          -0.265   Prob(JB):                     2.85e-67
# Kurtosis:                       3.949   Cond. No.                     8.00e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large,  8e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
